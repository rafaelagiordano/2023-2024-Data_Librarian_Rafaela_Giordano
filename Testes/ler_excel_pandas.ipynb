# %%
import pandas as pd

# %%
df = pd.read_excel("tree_data.xlsx")

# %%
df
# Out:
#                 Level1                Level2  \
# 0      Einzelne Länder                Afrika
# 1      Einzelne Länder                 Asien
# 2      Einzelne Länder                 Asien
# 3      Einzelne Länder            Australien
# 4      Einzelne Länder         Mittelamerika
# ..                 ...                   ...
# 361  Europäische Union  EG: XVII Zivilrecht.
# 362  Europäische Union  EG: XVII Zivilrecht.
# 363  Europäische Union  EG: XVII Zivilrecht.
# 364  Europäische Union  EG: XVII Zivilrecht.
# 365  Europäische Union  EG: XVII Zivilrecht.
#
#                                       Level3      Level4 Level5 Level6
# 0                                        NaN         NaN    NaN    NaN
# 1                                      Japan   OA/Jap: I    NaN    NaN
# 2                                      Japan  OA/Jap: II    NaN    NaN
# 3                                        NaN         NaN    NaN    NaN
# ...
