# %% [markdown]
# # Como abrir uma tabela em csv usando o pandas:

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.head()
# Out:
# /tmp/ipykernel_18140/1714274953.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# ...

# %% [markdown]
# # Como transformar um arquivo csv em uma arquivo json: df.to_json

# %%
df.to_json("../data/Library_Usage.json")

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
pd.to_numeric
# Out:
# <function pandas.core.tools.numeric.to_numeric(arg, errors: 'DateTimeErrorChoices' = 'raise', downcast: "Literal[('integer', 'signed', 'unsigned', 'float')] | None" = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>)>

# %%
pd.crosstab
# Out:
# <function pandas.core.reshape.pivot.crosstab(index, columns, values=None, rownames=None, colnames=None, aggfunc=None, margins: 'bool' = False, margins_name: 'Hashable' = 'All', dropna: 'bool' = True, normalize: 'bool' = False) -> 'DataFrame'>

# %%
df = pd.read_csv("../data/Library_Usage_Small.csv")
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
# 2                 0                  Adult                0               0
# 3                 2                   Teen                0               0
# 4                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# 1  10 to 19 years                 x                    Main
# 2  35 to 44 years                m4                  Merced
# 3  10 to 19 years                 x                    Main
# 4  10 to 19 years                b2                 Bayview
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
df
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
# 2                 0                  Adult                0               0
# 3                 2                   Teen                0               0
# 4                 2                   Teen                0               0
# 5                 2                   Teen                0               0
# 6                 2                   Teen                0               0
# 7                 2                   Teen                0               0
# 8                 0                  Adult                0               0
# 9                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# ...

# %%
df.to_json("../data/Library_Usage_Small.json")

# %%
df
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
# 2                 0                  Adult                0               0
# 3                 2                   Teen                0               0
# 4                 2                   Teen                0               0
# 5                 2                   Teen                0               0
# 6                 2                   Teen                0               0
# 7                 2                   Teen                0               0
# 8                 0                  Adult                0               0
# 9                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# ...

# %%
df.to_html("../data/Library_Usage_Small.html")

# %%
df
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
# 2                 0                  Adult                0               0
# 3                 2                   Teen                0               0
# 4                 2                   Teen                0               0
# 5                 2                   Teen                0               0
# 6                 2                   Teen                0               0
# 7                 2                   Teen                0               0
# 8                 0                  Adult                0               0
# 9                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# ...

# %%
df = pd.read_html("../data/Library_Usage_Small.html")
df
# Out:
# [   Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
#  0           0                 1               Juvenile                0
#  1           1                 2                   Teen                0
#  2           2                 0                  Adult                0
#  3           3                 2                   Teen                0
#  4           4                 2                   Teen                0
#  5           5                 2                   Teen                0
#  6           6                 2                   Teen                0
#  7           7                 2                   Teen                0
#  8           8                 0                  Adult                0
#  9           9                 2                   Teen                0
#
#     Total Renewals       Age Range Home Library Code Home Library Definition  \
#  0               0    0 to 9 years                r3                Richmond
# ...

# %%
df.to_excel("../data/Library_Usage_Small.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df.to_excel("../data/Library_Usage_Small.xlsx")
#
# AttributeError: 'list' object has no attribute 'to_excel'

# %%
df
# Out:
# [   Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
#  0           0                 1               Juvenile                0
#  1           1                 2                   Teen                0
#  2           2                 0                  Adult                0
#  3           3                 2                   Teen                0
#  4           4                 2                   Teen                0
#  5           5                 2                   Teen                0
#  6           6                 2                   Teen                0
#  7           7                 2                   Teen                0
#  8           8                 0                  Adult                0
#  9           9                 2                   Teen                0
#
#     Total Renewals       Age Range Home Library Code Home Library Definition  \
#  0               0    0 to 9 years                r3                Richmond
# ...

# %%
df.to_csv("../data/Library_Usage_Small1.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_csv("../data/Library_Usage_Small1.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
df
# Out:
# [   Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
#  0           0                 1               Juvenile                0
#  1           1                 2                   Teen                0
#  2           2                 0                  Adult                0
#  3           3                 2                   Teen                0
#  4           4                 2                   Teen                0
#  5           5                 2                   Teen                0
#  6           6                 2                   Teen                0
#  7           7                 2                   Teen                0
#  8           8                 0                  Adult                0
#  9           9                 2                   Teen                0
#
#     Total Renewals       Age Range Home Library Code Home Library Definition  \
#  0               0    0 to 9 years                r3                Richmond
# ...

# %%
df.memory_usage()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.memory_usage()
#
# AttributeError: 'list' object has no attribute 'memory_usage'

# %%
df.memory_usage(deep=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.memory_usage(deep=True)
#
# AttributeError: 'list' object has no attribute 'memory_usage'

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.info()
#
# AttributeError: 'list' object has no attribute 'info'

# %%
df.info(memory_usage='deep')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.info(memory_usage='deep')
#
# AttributeError: 'list' object has no attribute 'info'

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv")
df.columns
# Out:
# /tmp/ipykernel_18140/226503331.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Within San Francisco County'],
#       dtype='object')

# %%
x = df['Total Renewals']
df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(x)
print(subset)
# Out:
# 0           15
# 1          378
# 2           33
# 3         2140
# 4         1035
#           ...
# 436285       6
# 436286       0
# 436287       0
# 436288       0
# 436289     101
# Name: Total Renewals, Length: 436290, dtype: int64
#         Total Renewals  Total Checkouts
# 0                   15               53
# 1                  378              480
# 2                   33               70
# 3                 2140             3934
# 4                 1035             1118
# ...                ...              ...
# 436285               6                2
# 436286               0                3
# 436287               0                6
# 436288               0                4
# 436289             101              309
#
# [436290 rows x 2 columns]

# %% [markdown]
# # 2.5 Fallstudie: Feature Engineering

# %%
import pandas as pd
df = pd.read_json("../data/Library_Usage.json")
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15               None                b2
# 1                  378               None                e9
# ...

# %%
df['Circulation Active Year']
# Out:
# 0         2023.0
# 1         2023.0
# 2         2023.0
# 3         2023.0
# 4         2023.0
#            ...
# 436285    2022.0
# 436286    2015.0
# 436287    2022.0
# 436288    2020.0
# 436289    2023.0
# Name: Circulation Active Year, Length: 436290, dtype: float64

# %%
pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)
# Out:
# 0         2023.0
# 1         2023.0
# 2         2023.0
# 3         2023.0
# 4         2023.0
#            ...
# 436285    2022.0
# 436286    2015.0
# 436287    2022.0
# 436288    2020.0
# 436289    2023.0
# Name: Circulation Active Year, Length: 436290, dtype: float64

# %%
df['Circulation Active Month'] = pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%b"
)
df['Circulation Active Month']
# Out:
# 0        1900-03-01
# 1        1900-06-01
# 2        1900-01-01
# 3        1900-07-01
# 4        1900-07-01
#             ...
# 436285   1900-10-01
# 436286   1900-11-01
# 436287   1900-03-01
# 436288   1900-09-01
# 436289   1900-07-01
# Name: Circulation Active Month, Length: 436290, dtype: datetime64[ns]

# %%
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month
df['Circulation Active Month']
# Out:
# 0          3.0
# 1          6.0
# 2          1.0
# 3          7.0
# 4          7.0
#           ...
# 436285    10.0
# 436286    11.0
# 436287     3.0
# 436288     9.0
# 436289     7.0
# Name: Circulation Active Month, Length: 436290, dtype: float64

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15               None                b2
# 1                  378               None                e9
# ...

# %%
df['Year Patron Registered']
# Out:
# 0         2003
# 1         2003
# 2         2011
# 3         2003
# 4         2003
#           ...
# 436285    2020
# 436286    2011
# 436287    2022
# 436288    2019
# 436289    2003
# Name: Year Patron Registered, Length: 436290, dtype: int64

# %%
df['Membership Duration'] = (df['Circulation Active Year'] - df['Year Patron Registered'])

# %%
df['Membership Duration']
# Out:
# 0         20.0
# 1         20.0
# 2         12.0
# 3         20.0
# 4         20.0
#           ...
# 436285     2.0
# 436286     4.0
# 436287     0.0
# 436288     1.0
# 436289    20.0
# Name: Membership Duration, Length: 436290, dtype: float64

# %%
df['Membership Duration'] = (
    df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']

# %%
df['Membership Duration']
# Out:
# 0         243.0
# 1         246.0
# 2         145.0
# 3         247.0
# 4         247.0
#           ...
# 436285     34.0
# 436286     59.0
# 436287      3.0
# 436288     21.0
# 436289    247.0
# Name: Membership Duration, Length: 436290, dtype: float64

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
#
#         Age Range Home Library Code Home Library Definition  \
# 0            None                b2                 Bayview
# 1            None                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3            None                o2              Ocean View
# 4            None                o7                  Ortega
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
df.to_csv('../data/Library_Usage_Membership.csv', index=False)

# %%
df['Membership Duration'].fillna(0)
# Out:
# 0         243.0
# 1         246.0
# 2         145.0
# 3         247.0
# 4         247.0
#           ...
# 436285     34.0
# 436286     59.0
# 436287      3.0
# 436288     21.0
# 436289    247.0
# Name: Membership Duration, Length: 436290, dtype: float64

# %% [markdown]
# # Como limpar tabelas de dados que nao interessam, com Funktionen isna(), notna(), dropna() und fillna() an um fehlende Werte zu identifizieren, zu entfernen oder mit anderen Werten zu ersetzen.

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',
                 low_memory=False
                )

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      5                  Staff               53
# 1                      5                  Staff              480
# 2                      5                  Staff               70
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 0                   15                NaN                b2
# 1                  378                NaN                e9
# ...

# %%
df[df['Age Range'].isna()]
df[df['Age Range'].notna()]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 2                      5                  Staff               70
# 5                      5                  Staff             2635
# 6                      5                  Staff              774
# 7                      5                  Staff              508
# 9                      5                  Staff              110
# ...                  ...                    ...              ...
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 2                   33     45 to 54 years                n4
# 5                 4075     45 to 54 years                w2
# ...

# %%
df.isna().sum()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         912
# Home Library Code                   2
# Home Library Definition            30
# Circulation Active Month        39513
# Circulation Active Year         39513
# Notice Preference Code          42989
# Notice Preference Definition    42989
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County      1207
# dtype: int64

# %%
len(df) - df.count()
# Out:
# Patron Type Code                    0
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         912
# Home Library Code                   2
# Home Library Definition            30
# Circulation Active Month        39513
# Circulation Active Year         39513
# Notice Preference Code          42989
# Notice Preference Definition    42989
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County      1207
# dtype: int64

# %%
df_clean = df.dropna()
df_clean.isna().sum()
# Out:
# Patron Type Code                0
# Patron Type Definition          0
# Total Checkouts                 0
# Total Renewals                  0
# Age Range                       0
# Home Library Code               0
# Home Library Definition         0
# Circulation Active Month        0
# Circulation Active Year         0
# Notice Preference Code          0
# Notice Preference Definition    0
# Provided Email Address          0
# Year Patron Registered          0
# Within San Francisco County     0
# dtype: int64

# %%
df_clean
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 2                      5                  Staff               70
# 5                      5                  Staff             2635
# 6                      5                  Staff              774
# 7                      5                  Staff              508
# 9                      5                  Staff              110
# ...                  ...                    ...              ...
# 435078                 0                  Adult                0
# 435079                 3                 Senior                0
# 435080                 3                 Senior                0
# 435081                 3                 Senior                0
# 435082                 0                  Adult                0
#
#         Total Renewals          Age Range Home Library Code  \
# 2                   33     45 to 54 years                n4
# 5                 4075     45 to 54 years                w2
# ...

# %%
len(df) - len(df_clean)
# Out:
# 78452

# %%
df_clean.to_csv('../data/Library_Usage_Clean.csv', index=False)

# %%
# !head "../data/Library_Usage_Clean.csv"
# Out:
# Patron Type Code,Patron Type Definition,Total Checkouts,Total Renewals,Age Range,Home Library Code,Home Library Definition,Circulation Active Month,Circulation Active Year,Notice Preference Code,Notice Preference Definition,Provided Email Address,Year Patron Registered,Within San Francisco County
# 5,Staff,70,33,45 to 54 years,n4,Noe Valley,Jan,2023.0,z,Email,True,2011,False
# 5,Staff,2635,4075,45 to 54 years,w2,West Portal,Jul,2023.0,z,Email,True,2003,False
# 5,Staff,774,218,55 to 59 years,x,Main,Jul,2023.0,z,Email,True,2003,False
# 5,Staff,508,330,45 to 54 years,x,Main,Jul,2023.0,z,Email,True,2005,False
# 5,Staff,110,41,45 to 54 years,x,Main,Mar,2023.0,z,Email,True,2016,False
# 5,Staff,146,259,60 to 64 years,x,Main,Jul,2023.0,z,Email,True,2008,False
# 5,Staff,363,213,55 to 59 years,x,Main,Jul,2023.0,z,Email,True,2003,False
# 5,Staff,670,391,55 to 59 years,x,Main,Jul,2023.0,z,Email,True,2003,False
# 5,Staff,762,563,45 to 54 years,x,Main,Jul,2023.0,z,Email,True,2003,False

# %%
# !head -n 1 "../data/Library_Usage_Clean.csv"
# Out:
# Patron Type Code,Patron Type Definition,Total Checkouts,Total Renewals,Age Range,Home Library Code,Home Library Definition,Circulation Active Month,Circulation Active Year,Notice Preference Code,Notice Preference Definition,Provided Email Address,Year Patron Registered,Within San Francisco County

# %%
import pandas as pd
df = pd.read_csv('../data/Library_Usage.csv',
                 low_memory=False
                )
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
# 2                 5                  Staff               70              33
# 3                 5                  Staff             3934            2140
# 4                 5                  Staff             1118            1035
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# 4             NaN                o7                  Ortega
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# ...

# %%
df.tail()
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 436285                 0                  Adult                2
# 436286                 2                   Teen                3
# 436287                 0                  Adult                6
# 436288                15           Teacher Card                4
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 436285               6     35 to 44 years               yjj
# 436286               0     10 to 19 years               yjj
# 436287               0     60 to 64 years               ylw
# 436288               0     35 to 44 years               ylw
# 436289             101  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 436285              Bookmobile                      Oct
# 436286              Bookmobile                      Nov
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436290 entries, 0 to 436289
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Patron Type Code              436290 non-null  int64
#  1   Patron Type Definition        436290 non-null  object
#  2   Total Checkouts               436290 non-null  int64
#  3   Total Renewals                436290 non-null  int64
#  4   Age Range                     435378 non-null  object
#  5   Home Library Code             436288 non-null  object
#  6   Home Library Definition       436260 non-null  object
#  7   Circulation Active Month      396777 non-null  object
#  8   Circulation Active Year       396777 non-null  float64
#  9   Notice Preference Code        393301 non-null  object
#  10  Notice Preference Definition  393301 non-null  object
#  11  Provided Email Address        436290 non-null  bool
# ...

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count      436290.000000                 436290    436290.000000
# unique               NaN                     17              NaN
# top                  NaN                  Adult              NaN
# freq                 NaN                 274682              NaN
# mean            1.081295                    NaN       160.294843
# std             3.383103                    NaN       537.923680
# min             0.000000                    NaN         0.000000
# 25%             0.000000                    NaN         0.000000
# 50%             0.000000                    NaN         7.000000
# 75%             1.000000                    NaN        78.000000
# max           104.000000                    NaN     45380.000000
#
#         Total Renewals       Age Range Home Library Code  \
# count    436290.000000          435378            436288
# unique             NaN              10                75
# ...

# %%
print(df.mean())
print(df['Total Renewals'].mean())

# %%
df['Total Renewals'].sum()
df['Total Renewals'].between(100, 200).sum()

# %%
df.columns

# %%
df.dtypes

# %%
df.shape

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage.csv",
                low_memory=False)
df.loc[df['Total Checkouts'] > 10000]

# %%
df['Patron Type Definition'].unique()

# %%
df['Age Range'].unique()

# %%
row_filter = df['Total Checkouts'] > 10000
df.loc[row_filter]

# %%
row_filter = df['Total Checkouts'] == 0, ["Patron Type Definition"]
df.loc[row_filter]

# %%
row_filter = (df['Patron Type Definition'] == 'Senior') & (df['Notice Preference Definition'] == 'Email')
df.loc[row_filter]

# %%
row_filter = (df['Patron Type Definition'] == 'Welcome') & (df['Total Checkouts'] == 0)
df.loc[row_filter]

# %%
kinder_unter_10 = (df['Patron Type Definition'] == 'Juvenile')
df.loc[kinder_unter_10]

# %%
kinder_unter_10 = (df['Patron Type Definition'] == 'Juvenile') & (df['Age Range'] == '0 to 9 years')
df.loc[kinder_unter_10]

# %%
# Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du?

print(len(df[df['Age Range'] == '0 to 9 years']))

# %%
# Alternative
(df['Age Range'] == '0 to 9 years').sum()

# %%
row_filter = df['Total Checkouts'] > 20000
df.loc[row_filter]

# %%
print(len(df[df['Total Checkouts'] > 20000]))

# %%
(df['Total Checkouts'] > 20000).sum()

# %%
print(len(df[df['Home Library Definition'] == 'Richmond']))

# %%
# alternative
(df['Home Library Definition'] == 'Richmond').sum()

# %%
# Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?

# Hierfür wird die in Aufgabe 2.5 neu definierte Variable 'Membership Duration' benötigt. 
# Entweder rechnest Du mit der gleichen Datei wie aus Aufgabe 2.5 weiter, oder führst die dortigen Schritte
# noch einmal durch

### erneute Berechnung von 'Membership Duration' ###
#df['Circulation Active Year'] = pd.to_numeric(
#    df['Circulation Active Year'], errors='coerce'
#)
#
#df['Circulation Active Month'] = pd.to_datetime(
#    df['Circulation Active Month'],
#    errors='coerce',
#    format="%b"
#)
#
#df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

#df['Membership Duration'] = (
#   df['Circulation Active Year'] - df['Year Patron Registered']
#)*12 + df['Circulation Active Month']
#df['Membership Duration'] = df['Membership Duration'].fillna(0)
####                                             ###

print(len(df[df['Membership Duration'] == 0])/len(df))

# alternative
(df['Membership Duration'] == 0).mean()

# %%
import pandas as pd
df = pd.read_csv("../data/Library_Usage_Membership.csv",
                low_memory=False)

# %%
df

# %%
df['Age Range'].isna().sum()

# %%
len(df[(df['Age Range'] == '60 to 64 years') & (df['Circulation Active Year'] == 2016)])
