# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
sns.set_theme()

# %%
df = pd.read_csv("../data/Library_Usage.csv",
    low_memory=False
)

# %%
df.head(30)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  5                  Staff               53              15
# 1                  5                  Staff              480             378
# 2                  5                  Staff               70              33
# 3                  5                  Staff             3934            2140
# 4                  5                  Staff             1118            1035
# 5                  5                  Staff             2635            4075
# 6                  5                  Staff              774             218
# 7                  5                  Staff              508             330
# 8                  5                  Staff              178              27
# 9                  5                  Staff              110              41
# 10                 5                  Staff             1058            1264
# 11                 5                  Staff              146             259
# 12                 5                  Staff              384             457
# 13                 5                  Staff             2917            4489
# 14                 5                  Staff              363             213
# 15                 5                  Staff             1099             678
# 16                 5                  Staff              637             250
# 17                 5                  Staff             1486            2594
# 18                 5                  Staff              381              46
# 19                 5                  Staff              670             391
# 20                 5                  Staff             1289            1130
# 21                 5                  Staff              762             563
# 22                 5                  Staff             2053            1923
# 23                 5                  Staff               32               9
# 24                 5                  Staff               97              82
# 25                 5                  Staff              456             131
# 26                 5                  Staff              843             234
# 27                 5                  Staff             1003            1218
# 28                 5                  Staff              315              10
# 29                 4                Welcome                0               0
#
#          Age Range Home Library Code Home Library Definition  \
# 0              NaN                b2                 Bayview
# 1              NaN                e9               Excelsior
# 2   45 to 54 years                n4              Noe Valley
# 3              NaN                o2              Ocean View
# 4              NaN                o7                  Ortega
# 5   45 to 54 years                w2             West Portal
# 6   55 to 59 years                 x                    Main
# 7   45 to 54 years                 x                    Main
# 8              NaN                 x                    Main
# 9   45 to 54 years                 x                    Main
# 10             NaN                 x                    Main
# 11  60 to 64 years                 x                    Main
# 12             NaN                 x                    Main
# 13             NaN                 x                    Main
# 14  55 to 59 years                 x                    Main
# 15             NaN                 x                    Main
# 16             NaN                 x                    Main
# 17             NaN                 x                    Main
# 18             NaN                 x                    Main
# 19  55 to 59 years                 x                    Main
# 20             NaN                 x                    Main
# 21  45 to 54 years                 x                    Main
# 22             NaN                 x                    Main
# 23             NaN                 x                    Main
# 24             NaN                 x                    Main
# 25             NaN                 x                    Main
# 26  60 to 64 years                 x                    Main
# 27  55 to 59 years                 x                    Main
# 28             NaN                 x                    Main
# 29  25 to 34 years                 x                    Main
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                       Mar                   2023.0                      z
# 1                       Jun                   2023.0                      z
# 2                       Jan                   2023.0                      z
# 3                       Jul                   2023.0                      z
# 4                       Jul                   2023.0                      z
# 5                       Jul                   2023.0                      z
# 6                       Jul                   2023.0                      z
# 7                       Jul                   2023.0                      z
# 8                       Apr                   2020.0                      z
# 9                       Mar                   2023.0                      z
# 10                      Jul                   2023.0                      z
# 11                      Jul                   2023.0                      z
# 12                      Jul                   2023.0                      z
# 13                      Jul                   2023.0                      z
# 14                      Jul                   2023.0                      z
# 15                      Jul                   2023.0                      z
# 16                      Jul                   2023.0                      z
# 17                      Jul                   2023.0                      z
# 18                      Jul                   2023.0                      z
# 19                      Jul                   2023.0                      z
# 20                      Jul                   2023.0                      z
# 21                      Jul                   2023.0                      z
# 22                      Jul                   2023.0                      z
# 23                      Dec                   2018.0                      z
# 24                      Jul                   2023.0                      z
# 25                      Apr                   2022.0                      z
# 26                      Jun                   2020.0                      z
# 27                      Jul                   2023.0                      z
# 28                      Apr                   2023.0                    NaN
# 29                      Oct                   2019.0                      z
#
#    Notice Preference Definition  Provided Email Address  \
# 0                         Email                    True
# 1                         Email                    True
# 2                         Email                    True
# 3                         Email                    True
# 4                         Email                    True
# 5                         Email                    True
# 6                         Email                    True
# 7                         Email                    True
# 8                         Email                    True
# 9                         Email                    True
# 10                        Email                    True
# 11                        Email                    True
# 12                        Email                    True
# 13                        Email                    True
# 14                        Email                    True
# 15                        Email                    True
# 16                        Email                    True
# 17                        Email                    True
# 18                        Email                    True
# 19                        Email                    True
# 20                        Email                    True
# 21                        Email                    True
# 22                        Email                    True
# 23                        Email                    True
# 24                        Email                    True
# 25                        Email                    True
# 26                        Email                    True
# 27                        Email                    True
# 28                          NaN                   False
# 29                        Email                    True
#
#     Year Patron Registered Within San Francisco County
# 0                     2003                       False
# 1                     2003                       False
# 2                     2011                       False
# 3                     2003                       False
# 4                     2003                       False
# 5                     2003                       False
# 6                     2003                       False
# 7                     2005                       False
# 8                     2003                       False
# 9                     2016                       False
# 10                    2003                       False
# 11                    2008                       False
# 12                    2003                       False
# 13                    2003                       False
# 14                    2003                       False
# 15                    2003                       False
# 16                    2003                       False
# 17                    2003                       False
# 18                    2006                       False
# 19                    2003                       False
# 20                    2003                       False
# 21                    2003                       False
# 22                    2003                       False
# 23                    2003                       False
# 24                    2021                       False
# 25                    2003                       False
# 26                    2003                       False
# 27                    2003                       False
# 28                    2003                       False
# 29                    2019                       False

# %%
sns.barplot(
    data=df, y="Age Range", x="Total Checkouts",
    estimator="mean", errorbar=None,
    ).set(title="Total Checkouts per faixa etaria")
# Out:
# [Text(0.5, 1.0, 'Total Checkouts per faixa etaria')]

# %%
average_checkouts = (
    tips
    .groupby("day")["tip"]
   ...:     .mean()
   ...: )
   ...:
   ...: days = ["Thur", "Fri", "Sat", "Sun"]
   ...: daily_averages = [
   ...:     average_daily_tip["Thur"],
   ...:     average_daily_tip["Fri"],
   ...:     average_daily_tip["Sat"],
   ...:     average_daily_tip["Sun"],
   ...: ]
   ...:
   ...: fig, ax = plt.subplots()
   ...: plt.bar(x=days, height=daily_averages)
   ...: ax.set_xlabel("day")
   ...: ax.set_ylabel("tip")
   ...: ax.set_title("Daily Tips ($)")
   ...:
   ...: plt.show()
