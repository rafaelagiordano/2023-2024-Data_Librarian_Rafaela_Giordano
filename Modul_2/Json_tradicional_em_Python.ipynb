# %%
import json

# %%
url = "https://www.bibsonomy.org/json/search/portuguese?items=100&duplicates=merged"

# %%
import urllib.request
import urllib.parse

f = urllib.request.urlopen(url) # f ist eine HTTPResponse
result = f.read().decode("UTF-8") # utf-8 ist oft die richtige Wahl für sprache code

# %% [raw]
# print(type(result))

# %%
data = json.loads(result)
print(type(data))
# Out:
# <class 'dict'>

# %%
import requests

# %%
result = requests.get(url)

# %%
data = result.json()

# %%
type(data)
# Out:
# dict

# %%
print(data)
# Out:
# {'types': {'Bookmark': {'pluralLabel': 'Bookmarks'}, 'Publication': {'pluralLabel': 'Publications'}, 'GoldStandardPublication': {'pluralLabel': 'GoldStandardPublications'}, 'GoldStandardBookmark': {'pluralLabel': 'GoldStandardBookmarks'}, 'Tag': {'pluralLabel': 'Tags'}, 'User': {'pluralLabel': 'Users'}, 'Group': {'pluralLabel': 'Groups'}, 'Sphere': {'pluralLabel': 'Spheres'}}, 'properties': {'count': {'valueType': 'number'}, 'date': {'valueType': 'date'}, 'changeDate': {'valueType': 'date'}, 'url': {'valueType': 'url'}, 'id': {'valueType': 'url'}, 'tags': {'valueType': 'item'}, 'user': {'valueType': 'item'}}, 'items': [{'type': 'Bookmark', 'id': 'https://www.bibsonomy.org/url/e56f0b7d34bd0e96895022e4952fe118/lalgarra', 'tags': ['sitepal'], 'intraHash': 'e56f0b7d34bd0e96895022e4952fe118', 'label': 'SitePal - Portuguese', 'user': 'lalgarra', 'description': '', 'date': '2006-07-11 14:49:03', 'changeDate': '2007-05-28 07:02:50', 'count': 1, 'url': 'http://www.oddcast.com/sitepal/portugue
# ...

# %%
print(json.dumps(data, indent=2))
# Out:
# {
#   "types": {
#     "Bookmark": {
#       "pluralLabel": "Bookmarks"
#     },
#     "Publication": {
#       "pluralLabel": "Publications"
#     },
#     "GoldStandardPublication": {
#       "pluralLabel": "GoldStandardPublications"
#     },
#     "GoldStandardBookmark": {
#       "pluralLabel": "GoldStandardBookmarks"
#     },
#     "Tag": {
#       "pluralLabel": "Tags"
#     },
#     "User": {
#       "pluralLabel": "Users"
#     },
#     "Group": {
#       "pluralLabel": "Groups"
#     },
#     "Sphere": {
#       "pluralLabel": "Spheres"
#     }
#   },
#   "properties": {
#     "count": {
#       "valueType": "number"
#     },
#     "date": {
#       "valueType": "date"
#     },
#     "changeDate": {
#       "valueType": "date"
#     },
#     "url": {
#       "valueType": "url"
#     },
#     "id": {
#       "valueType": "url"
#     },
#     "tags": {
#       "valueType": "item"
#     },
#     "user": {
#       "valueType": "item"
#     }
#   },
#   "items": [
#     {
# ...

# %%
from pprint import pprint
pprint(data)
# Out:
# {'items': [{'changeDate': '2007-05-28 07:02:50',
#             'count': 1,
#             'date': '2006-07-11 14:49:03',
#             'description': '',
#             'id': 'https://www.bibsonomy.org/url/e56f0b7d34bd0e96895022e4952fe118/lalgarra',
#             'intraHash': 'e56f0b7d34bd0e96895022e4952fe118',
#             'label': 'SitePal - Portuguese',
#             'tags': ['sitepal'],
#             'type': 'Bookmark',
#             'url': 'http://www.oddcast.com/sitepal/portuguese',
#             'user': 'lalgarra'},
#            {'changeDate': '2011-10-01 02:38:09',
#             'count': 1,
#             'date': '2011-10-01 02:26:40',
#             'description': 'a Multiplayer First Person Shooter(MFPS) Game '
#                            'based on the Portuguese colonial war in Africa ( '
#                            'Angola,Mocambique and Guiné ) in the years of 1960 '
#                            'until 25/04/1974',
# ...

# %%
print(data.keys())
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
eintraege = data["items"]
print(type(items))
print(len(items))
# Out:
# <class 'list'>
# 200

# %%
publications = [item for item in eintraege if item["type"] == "Publication"]
print(len(publications))
# Out:
# 100

# %%
pubs_with_abstracts = [item for item in publications if "abstract" in item]
print(len(pubs_with_abstracts))
# Out:
# 36

# %%
with open("pubs_with_abstracts", "w") as publicomresumos:
    json.dump(pubs_with_abstracts, publicomresumos, indent=4)

# %%
print(json.dumps(pubs_with_abstracts, indent=4))
# Out:
# [
#     {
#         "type": "Publication",
#         "id": "https://www.bibsonomy.org/bibtex/268657380cb611e68667aba88db6ad42a/ijtsrd",
#         "tags": [
#             "Literature",
#             "Novel",
#             "Portuguese",
#             "Narrative",
#             "Adaptation"
#         ],
#         "intraHash": "68657380cb611e68667aba88db6ad42a",
#         "interHash": "465143f1607c8c11f1e9cbf8157a2d75",
#         "label": "Portuguese Literature, Narrative and Semiotic Construction From Literary Origin to the Process of Adaptation of Narrative in Cinema A Bridge Between Portuguese Literature and Universal Literature",
#         "user": "ijtsrd",
#         "description": "",
#         "date": "2020-05-13 12:47:52",
#         "changeDate": "2020-05-13 12:47:52",
#         "count": 1,
#         "pub-type": "article",
#         "journal": "International Journal of Trend in Scientific Research and Development",
#         "year": "2020",
# ...
