# %% [markdown]
# # como fazer para ler um arquivo de texto, usando open e .read

# %%
file_for_reading = open("gulliver.txt", "r")

# %%
type(file_for_reading)
# Out:
# _io.TextIOWrapper

# %%
file_for_reading
# Out:
# <_io.TextIOWrapper name='gulliver.txt' mode='r' encoding='UTF-8'>

# %%
first_20_chars = file_for_reading.read(21)
first_20_chars
# Out:
# 'The Project Gutenberg'

# %%
# !head gulliver.txt
# Out:
# The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift
#
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org

# %%
file_for_reading.read()
# Out:
# ' eBook, Gulliver\'s Travels, by Jonathan Swift\n\n\nThis eBook is for the use of anyone anywhere at no cost and with\nalmost no restrictions whatsoever.  You may copy it, give it away or\nre-use it under the terms of the Project Gutenberg License included\nwith this eBook or online at www.gutenberg.org\n\n\n\n\n\nTitle: Gulliver\'s Travels\n       into several remote nations of the world\n\n\nAuthor: Jonathan Swift\n\n\n\nRelease Date: June 15, 2009  [eBook #829]\n\nLanguage: English\n\nCharacter set encoding: UTF-8\n\n\n***START OF THE PROJECT GUTENBERG EBOOK GULLIVER\'S TRAVELS***\n\n\nTranscribed from the 1892 George Bell and Sons edition by David Price,\nemail ccx074@pglaf.org\n\n\n\n\n\n                            GULLIVER’S TRAVELS\n                               INTO SEVERAL\n                       REMOTE NATIONS OF THE WORLD\n\n\n                         BY JONATHAN SWIFT, D.D.,\n                      DEAN OF ST. PATRICK’S, DUBLIN.\n\n                      [_First published 
# ...

# %%
next_line = file_for_reading.readline()
next_line
# Out:
# ''

# %%
whole_text = file_for_reading.readlines()
whole_text
# Out:
# []

# %%
file_for_reading.close()

# %%
with open ("gulliver.txt", "r") as infile:
    data = infile.readlines()
    print(data)
# Out:
# ["The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift\n", '\n', '\n', 'This eBook is for the use of anyone anywhere at no cost and with\n', 'almost no restrictions whatsoever.  You may copy it, give it away or\n', 're-use it under the terms of the Project Gutenberg License included\n', 'with this eBook or online at www.gutenberg.org\n', '\n', '\n', '\n', '\n', '\n', "Title: Gulliver's Travels\n", '       into several remote nations of the world\n', '\n', '\n', 'Author: Jonathan Swift\n', '\n', '\n', '\n', 'Release Date: June 15, 2009  [eBook #829]\n', '\n', 'Language: English\n', '\n', 'Character set encoding: UTF-8\n', '\n', '\n', "***START OF THE PROJECT GUTENBERG EBOOK GULLIVER'S TRAVELS***\n", '\n', '\n', 'Transcribed from the 1892 George Bell and Sons edition by David Price,\n', 'email ccx074@pglaf.org\n', '\n', '\n', '\n', '\n', '\n', '                            GULLIVER’S TRAVELS\n', '                               INTO SEVERAL\n', '                       REMOT
# ...

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# ["The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift\n",
#  '\n',
#  '\n',
#  'This eBook is for the use of anyone anywhere at no cost and with\n',
#  'almost no restrictions whatsoever.  You may copy it, give it away or\n',
#  're-use it under the terms of the Project Gutenberg License included\n',
#  'with this eBook or online at www.gutenberg.org\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  "Title: Gulliver's Travels\n",
#  '       into several remote nations of the world\n',
#  '\n',
#  '\n',
#  'Author: Jonathan Swift\n',
#  '\n',
#  '\n',
#  '\n',
#  'Release Date: June 15, 2009  [eBook #829]\n',
#  '\n',
#  'Language: English\n',
#  '\n',
#  'Character set encoding: UTF-8\n',
#  '\n',
#  '\n',
#  "***START OF THE PROJECT GUTENBERG EBOOK GULLIVER'S TRAVELS***\n",
#  '\n',
#  '\n',
#  'Transcribed from the 1892 George Bell and Sons edition by David Price,\n',
#  'email ccx074@pglaf.org\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
# ...

# %%
with open ("gulliver.txt", "r") as infile:
    for line in infile:
        print(line.strip())
# Out:
# The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift
#
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
#
#
#
# Title: Gulliver's Travels
# into several remote nations of the world
#
#
# Author: Jonathan Swift
#
#
#
# Release Date: June 15, 2009  [eBook #829]
#
# Language: English
#
# Character set encoding: UTF-8
#
#
# ***START OF THE PROJECT GUTENBERG EBOOK GULLIVER'S TRAVELS***
#
#
# Transcribed from the 1892 George Bell and Sons edition by David Price,
# email ccx074@pglaf.org
#
#
#
#
#
# GULLIVER’S TRAVELS
# INTO SEVERAL
# REMOTE NATIONS OF THE WORLD
#
#
# BY JONATHAN SWIFT, D.D.,
# DEAN OF ST. PATRICK’S, DUBLIN.
#
# [_First published in_ 1726–7.]
#
#
#
#
# THE PUBLISHER TO THE READER.
#
#
# [_As given in the original edition_.]
#
# ...

# %%
for line in open("gulliver.txt", "r"):
                 print(line.strip())
# Out:
# The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift
#
#
# This eBook is for the use of anyone anywhere at no cost and with
# almost no restrictions whatsoever.  You may copy it, give it away or
# re-use it under the terms of the Project Gutenberg License included
# with this eBook or online at www.gutenberg.org
#
#
#
#
#
# Title: Gulliver's Travels
# into several remote nations of the world
#
#
# Author: Jonathan Swift
#
#
#
# Release Date: June 15, 2009  [eBook #829]
#
# Language: English
#
# Character set encoding: UTF-8
#
#
# ***START OF THE PROJECT GUTENBERG EBOOK GULLIVER'S TRAVELS***
#
#
# Transcribed from the 1892 George Bell and Sons edition by David Price,
# email ccx074@pglaf.org
#
#
#
#
#
# GULLIVER’S TRAVELS
# INTO SEVERAL
# REMOTE NATIONS OF THE WORLD
#
#
# BY JONATHAN SWIFT, D.D.,
# DEAN OF ST. PATRICK’S, DUBLIN.
#
# [_First published in_ 1726–7.]
#
#
#
#
# THE PUBLISHER TO THE READER.
#
#
# [_As given in the original edition_.]
#
# ...

# %%
with open("gulliver1.txt", "w") as outfile:
    outfile.writelines(data[0])

# %%
for line in open("gulliver1.txt", "r"):
                 print(line.strip())
# Out:
# The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift

# %%
with open("gulliver1.txt", "a") as outfile:
    outfile.writelines(data[4])

# %%
for line in open("gulliver1.txt", "r"):
                 print(line.strip())
# Out:
# The Project Gutenberg eBook, Gulliver's Travels, by Jonathan Swift
# almost no restrictions whatsoever.  You may copy it, give it away or
